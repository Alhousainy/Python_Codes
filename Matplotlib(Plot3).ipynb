# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,10,0.5)
ax=plt.axes()
plt.style.use('ggplot')
ax.set(xlabel='X Axsis',ylabel='Y Axsis')
ax.set(title='Merge Functions')
plt.plot(x,x,'r--',x,x**2,'bo',x,x**3,'g^')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,10,.05)
ax=plt.axes()
plt.style.use('ggplot')
ax.set(xlabel='X Axsis',ylabel='Y Axsis')
ax.set_title('Complex Methods')
y=np.exp(-x/3)*np.sin(3*np.pi*x)
z=np.exp(x/2)*np.sin(3*np.pi*x)
w=np.exp(x/2)**np.cos(4*np.pi*x)
plt.plot(x,y,'b',x,z,'g',x,w,'r')

# %%
import numpy as np
import matplotlib.pyplot as plt
ax=plt.axes()
plt.style.use('ggplot')
ax.set(xlabel='X Axsis',ylabel='Y Axsis')
ax.set_title('Complex Functions')
x=np.linspace(0,10,500)
y=np.cumsum(np.random.randn(500,6),0)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
ax=plt.axes()
ax.set(xlabel='X Axsis',ylabel='Y Axsis')
ax.set(title='ErrorBar')
plt.style.use('ggplot')
x=np.linspace(0,10,50)
dy=0.2
y=np.sin(x)+dy*np.random.randn(50)
plt.errorbar(x,y,yerr=dy,fmt='.b')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
ax=plt.axes()
plt.style.use('ggplot')
ax.set(xlabel='X Axsis',ylabel='Y Axsis')
ax.set(title='ErrorBar1')
x=np.linspace(0,15,60)
dy=0.5
#np.sin(x)+dy*np.random.randn(50)
y=np.cos(x) + dy * np.random.randn(60)
plt.errorbar(x,y,yerr=dy,fmt='.g')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
ax=plt.axes()
plt.style.use('ggplot')
ax.set(xlabel='X Axsis',ylabel='Y Axsis')
ax.set(title='Color Marker and Error Bar')
x=np.linspace(0,10,60)
dy=2.5
y=np.sin(x) + dy * np.random.randn(60)
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',ecolor='lightgray',elinewidth=3,capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,50)
ax=plt.axes()
plt.style.use('ggplot')
ax.set_xlabel('X Axsis')
plt.ylabel('Y Axsis')
ax.set_title('Horizonatl ErrorBar')
dy=1.2
y=np.sin(x)+dy*np.random.rand(50)
plt.errorbar(x,y,xerr=dy,fmt='-g')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#D:\Programming\Machine learning Python\Files
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def extract_data(filename):
    infile=open(filename,'r')
    infile.readline()#skip the first Line
    numbers=[]
    for line in infile:
        words=line.split()
        number=float(words[1])
        numbers.append(number)
    infile.close()
    return numbers
values=extract_data('D:\\Programming\\Machine learning Python\\Files\\rainfill.txt')
print(values)
month_indices=range(1,13)
plt.plot(month_indices,values[:-1],'o')
# Out:
# [81.2, 63.2, 70.3, 55.7, 53.0, 36.4, 17.5, 27.5, 60.9, 117.7, 111.0, 97.9, 792.9]
