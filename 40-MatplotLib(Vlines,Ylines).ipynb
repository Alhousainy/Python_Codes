# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.vlines(0,-1,1,lw=4,color='orange')
plt.vlines(1,-1.5,5,lw=4,color='black')
plt.vlines(1.8,-2.3,8.5,lw=4,color='green')

# %%
import matplotlib.pyplot as plt
plt.vlines(0,-1,1,lw=5, color='r')

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')
plt.vlines(0,-1,1,lw=1,color='green')
plt.vlines(0.5,-1.3,2.5,lw=2.5,color='gray')
plt.vlines(1,-2.3,3.6,lw=5,color='black')
plt.vlines(1.5,-3,4.3,lw=7,color='orange')
plt.vlines(2.1,-3.8,7.5,lw=10,color='purple')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
L=[-1.5,-1,-.5,0,.5,1,1.5] 
plt.vlines(L,-1,1,lw=3.5,color='purple')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
L=[-1.5,-1,-.5,0,.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6] 
plt.vlines(L,-1,1,lw=3.5,color='purple')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
L=[-1.5,-1,-.5,0,.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6] 
plt.hlines(L,-1,1,lw=3.5,color='purple')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig,ax=plt.subplots()
ax.set(title='VLines & HLines',xlabel='X Axsis',ylabel='Y Axsis')
L=[-1.5,-1,-.5,0,.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6] 
plt.hlines(L,-1.5,6,lw=3.5,color='purple')
plt.vlines(L,-1.5,6,lw=4,color='green')
leg=ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
plt.hlines(-3,-1,1,lw=10, color='w')
plt.hlines(-2,-1,1,lw=10, color='b')
plt.hlines(-1,0,1,lw=10, color='b')
plt.hlines(1,0,1,lw=10, color='b')
plt.hlines(2,-1,1,lw=10, color='b')
plt.hlines(3,-1,1,lw=10, color='w')
plt.vlines(-2.5,-1,1,lw=10, color='w')
plt.vlines(-1,-2,2,lw=10, color='r')
plt.vlines(0,-1,1,lw=10, color='r')
plt.vlines(1,1,2,lw=10, color='r')
plt.vlines(1,-2,-1,lw=10, color='r')
plt.vlines(2.5,-1,1,lw=10, color='w')
